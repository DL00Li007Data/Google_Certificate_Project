# %% [markdown]
# ---
# title: "Google_Capstone_Project_Bellabeat_Case_with_R_DL"
# author: ""
# date: "2/7/2022"
# output: html_document
# ---
#
# ## **1. Introduction**
#
# The data comes from Bellabeat, a hight-tech manufacturer focused on women's health products. The data comes form the application of Bellabeat products, and the data source link is like this: see [https://www.kaggle.com/arashnic/fitbit].
# The App, Leaf and Spring's products contains relevant information about product users, such as Id, date, activity, sleep, stress, usage time, etc. As a data analyst, my goal is to develop product marketing strategies and high-level recommendations based on Bellabeat data.
#
#
#
# ## **2. Business Tasks**
#
#
#
# ### ** Step1: Ask- Understand the Problem. **
#
#     1) What are the treads in the use of smart devices?
#
#     2) How do these trends apply to Bellabeat customers?
#
#     3) How do these trends affect Bellabeat's marketing strategy?
#
#
#
# ### ** Step2: Prepare- What do I need **
#
#     1) Install related R packages
#
#     2) Obtain data sets through FitBit Fitness Tracker Data and import them into RStudio respectively.
#
#     3) In R, new data suitable for conditions could be obtained by merging, filtering, and extracting data sets.
#
#     4) Split the original data through Google Sheet filtering, extracting important parameters, filtering, and other operations to obtain a new data set.
#
#     5) Through SQL syntax in R, merge, filtering, and extracting to obtain new data sets that meet the conditions.
#
#
#
# ### ** Step3: Process- Make it Usable **
#
# I was using proper tools to find incorrect and incomplete data. Removing inconsistencies in data set, sometimes there might be duplicated entries.
#
# One of the most important aspects to keep in mind - identifying whether your data is biased.
# Essentially, biased data will not be representative of the population or phonomenon of study, the issue we are trying to solve.
#
#
#
# ### ** Step4: Analyze- Tell the Stackholders the Story **
#
#
#
# #### **A-part: Comprehensive Data Analysis**
#
# The total number of users of Bellabeat's data is 33 users, and I calculated the number and percentage of the 33 users using the User's categories, which contains five types of users(Activity, Intensities, Sleeps, Steps, Weight), and a column chart used to disinguish different types of color visually. The conclusion shows that Activity, Intensities, and Sleeps users account was 100% percentage. And Steps users account for 72.73%. And Weight account for 24.24%.
#
# Therefore, the utilization rate of the five product functions is very different. The hightest and the lowest utilization rate is 75% more. So, Bellabeat could refer to the last recommendation part to adjust the sales strategy.
#
#
# ##### **  -- About TotalMinutesAsleep vs Activity_levels vs TotalSteps analysis**
#
#     1) The total number of unique users is 131. We could intuitively detect which category has the most users from this combination result.
#
#     2) Divide TotalSteps into five categories: "Sedentary", "Low_Activities", "Medium_Activities", "Activities", "High_Activities".
#
#     Then, I divided TotalMinutesAsleep into three categories:"Low_Sleep", "Reasonalble_Sleep", "More_Sleep". Also, I divided the date into Monday to Sunday.
#
#     3) Display the above data through four sets of visualization diagrams, respectively.
#
#
# ##### **  -- Plot of TotalMinutesAsleep vs Activity_levels 1&2**
#
#     I got Sedentary with the longest sleep time in Activity_levels, and Acitvities with the shortest sleep time. The user sleep time interval distribution of Sendentary Acitivity is smoother, and the sleep time span is wider. The user peak of Activities is steeper, and the interval of sleep time is narrower.
#
#
# ##### **  -- BoxPlot of ActivityLevels_vs_TotalMinutesAsleep**
#
#     By extracting 200 seeds, the boxplot shows that the average sleep time of Sendentary Activity users is longer, and the leaset sleep time is Activities users.
#
#
# ##### **  -- Plot of Activity_Sleep vs Calories vs Day**
#
#     The figure displayed that the consumption of Calories on Thursday is the largest and has the largest span, and the consumption of Calories on Monday and Tuesday is the least. Sunday's sleeping area is the largest.
#
#
# ##### **  -- Plot of TotalSteps_vs_WeekDay**
#
#     According to the figure, which displayed that the total number of steps on Saturday is the highest in the week, the peak is also the hightest, and the fluctuation is very large. The peak on Sunday was the lowest. From the graph, we could see that the curve of the total number of steps in the first three days of the week fluctuates the same, and the peak value is almost the same, and the fluctuations have become larger and larger since Thursday.
#
#
#
# #### **B-part:Daily Analysis**
#
#
#
#  * 1) Get important parameter values, including max_date, min_date, different_days, max_users, max_TotalSteps, min_TotalSteps, Average_steps_Daily.
#
#
#  * 2) Obtain the required data set through SQL, and calculate the statistical correlation of related parameters.
#
#
# ##### **  -- Correlation for TotalSteps vs TotalMinutesAsleep vs Calories**
#
#     According to the statistical correlation, the visual map was obtained, and the correlation between TotalSteps and Calories was obtained, which proved that the records of Steps and Calories were consistent. But But TotalSteps vs TotalMinutesAsleep and Calories vs TotalMinutesAsleep were both negatively correlated, proving that two sets of data have opposite trends.
#
#
# ##### **  -- Plot for Steps_level Daily Through one Month**
#
#      Through this visualization, you can get daily data for one month between 04/12/16 - 05/12/16. Regarding users with more than average steps and less than average steps, the total number of daily users is 33.
#
#      Therefore, it displayed more users with a total of 9 days whose value is lower than the average number of steps, and more users with more than average number of steps on other days.
#
#
# ##### **  -- Plot of WeekDays vs TotalMinutesAsleep vs TotalSteps**
#
#      This graph provides a more direct view of the overall trend of sleep minutes and steps per day of the week. We could see that only Sunday's trend is parallel or even upward. The rest of the time is downtrend, and the trend on Saturday and Monday has a more negative slope.
#
#
# #### **C-part:Hourly Analysis**
#
#
#
#  *  Get important parameter values, including max_Calories_hourly, min_Calories_hourly, max_TotalIntensity_hourly, min_TotalIntensity_hourly, max_TotalSteps_hourly, min_TotalSteps_hourly, different_days.
#
#
# ##### **  -- Plot of Hours_of_Calories**
#
#     It could be displayed from the graph that Calories is the hightes during 14:00-18:00, and it is also the most concentrated during this period. It may be the time when everyone is working and going out every day, so the value of Calories is the hightest. The lowest Calories values exist daily between 02:00AM-04:00AM, and 12:00 noon, probably this is when people sleep and rest daily, so there won't be many exercises.
#
#
# ##### **  -- Plot of Hours_of_TotalIntensity**
#
#      The graph show that except noon, the value of Intensity is very high from 8:00-19:00 daily, probably because this is the working time, so there will be pressure.
#
#
# ##### **  -- **Plot of hours_of_steptotal**
#
#      According to this plot which illustrated from the graph, Steps has an upward trend from 6:00-9:00, 11:00:19:00, probably because this is the pace of working hours, and it is proof of people's hard work.
#
#
#
# ### ** Step5: Share-Get Different Views. **
#
#      At this point, I will be making a perfect PowerPoint to tell my story to the stakeholders, but we need to know that everyone is baised. So I should get more different opinions in this step, the feedback voice of stackholders is not only criticism, but also new views and new requirements about this report, so I should seize the opportunity to communicate with stakeholders, to gather more useful information.
#
#
#
# ### ** Step6: Ask- Understand the Problem. **
#
#     At this step, I will give the results and recommendations depending on my analysis, and I will provide the further actions which we could made. So, the decision-makers with my advices base on the analysis so they could make some data-driven decisions.
#     I put the specific recommendation at the bottom part.

# %% [markdown]
# ## **3.About the specific operation of step 4-Analyze**
#
#
#
# ### **A.1 Installing Packages**

# %%
library(data.table) # Import big files (CSV or Text) 
install.packages("tidyverse")
library(tidyverse)
library(readxl)

# %%
# Loading and Installing Packages

library(tidyverse)
library(dplyr)
library(lubridate)
library(ggplot2)
library(ggpubr)
library(tidyr)
library(readr)
library(skimr)
library(wesanderson)
library(knitr)
library(RSQLite)
library(sqldf)
library(ggtext)
library(ggridges)
library(RColorBrewer)

# %% [markdown]
# ## **A.2 Import data from csv files**

# %%
daily_activity <- read_csv("../input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyActivity_merged.csv")
daily_Calories <- read_csv("../input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyCalories_merged.csv")
weight_log <- read_csv("../input/fitbit/Fitabase Data 4.12.16-5.12.16/weightLogInfo_merged.csv")
sleep_Day <- read_csv("../input/fitbit/Fitabase Data 4.12.16-5.12.16/sleepDay_merged.csv")
daily_Steps<- read_csv("../input/fitbit/Fitabase Data 4.12.16-5.12.16/dailySteps_merged.csv")
daily_Intensities<- read_csv("../input/fitbit/Fitabase Data 4.12.16-5.12.16/dailyIntensities_merged.csv")
hourlyCalories <- read_csv("../input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlyCalories_merged.csv")
hourlyIntensities_merged <- read_csv("../input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlyIntensities_merged.csv")
hourlySteps_merged <- read_csv("../input/fitbit/Fitabase Data 4.12.16-5.12.16/hourlySteps_merged.csv")

# %% [markdown]
# ### **A.3 Assign Id/ User_category**
# For the following data sets, I would merge these data sets together by the same parameters. In order to take the analysis in one data set.

# %%
# Assign Id/ User_category
daily_activity_users <- daily_activity %>% 
  drop_na(Id) %>% 
  arrange(Id) %>% 
  distinct(Id) %>% 
  cbind(User_category = "Activity") %>% 
  select(Id, User_category)

daily_Intensities_users <- daily_Intensities %>% 
  drop_na(Id) %>% 
  arrange(Id) %>% 
  distinct(Id) %>% 
  cbind(User_category = "Intensities") %>% 
  select(Id, User_category)

daily_Steps_users <- daily_Steps %>% 
  drop_na(Id) %>% 
  arrange(Id) %>% 
  distinct(Id) %>% 
  cbind(User_category = "Steps") %>% 
  select(Id, User_category)

sleep_Day_users <- sleep_Day %>% 
  drop_na(Id) %>% 
  arrange(Id) %>% 
  distinct(Id) %>% 
  cbind(User_category = "Sleeps") %>% 
  select(Id, User_category)

weight_log_users <- weight_log %>% 
  drop_na(Id) %>% 
  arrange(Id) %>% 
  distinct(Id) %>% 
  cbind(User_category = "Weight") %>% 
  select(Id, User_category)

# %%
# Create overall dataframe 
User_distribution <- rbind( daily_activity_users, 
                            daily_Intensities_users,
                            daily_Steps_users,
                            sleep_Day_users, 
                            weight_log_users)
glimpse(User_distribution)

# %% [markdown]
# ### **A.4 Percentage of Activities**
#
# The total number of unique users is 131, from this combination result, we could intuitively detect which catagory has the most users. The Activity, Intensities, Sleeps three functions are customers' favourite. The Weight function is the least popular. The usage of the Sleep function is in the middle.

# %%
# Percentage of Usage
count_users <- length(unique(User_distribution$Id))

Percentage_of_Usage <- User_distribution %>% 
  group_by(User_category) %>% 
  summarise(count_User_category = n()) %>%
  mutate(Total_Percent_active = round((count_User_category / count_users),4)*100) 
  

ggplot(Percentage_of_Usage, aes(x=reorder(User_category,-Total_Percent_active), y=Total_Percent_active, fill=User_category)) +
  geom_bar(stat="identity")+
  labs(title = "Percentage_of_Activity", x="", y="Percentage_Activities", fill="User_Category")+
  scale_y_continuous(expand=c(0, 0)) +
  theme(axis.text.x=element_text(angle=45, hjust=1)) +
  theme(panel.grid=element_blank(), panel.background=element_rect(color='black', fill='transparent')) +
  geom_text(aes(x = User_category, y = Total_Percent_active, label = Total_Percent_active), colour = "white", size = 3, vjust = 2, fontface = "bold") +
    labs(
    title = "Percentage_of_Activity(% * 100)",
    subtitle = "Total_Users = 33",
    caption = "Source: FitBit Fitness Tracker Data",
    x = "User_Category"
  )

# %% [markdown]
# ### **A.5 Reorganize the date formate of Activity and Sleeps**
#
# Format and Rename the AcitivityDay to get the same format date, which could merge in the next step. Also, I use the case_when function to separate the different Activity_levels, Sleeps_levels and weekdays.

# %%
# Reorganize the date formate of Activity and Sleeps

Activity2 <- daily_activity %>% 
  mutate(ActivityDate = mdy(ActivityDate)) %>% 
  rename(Date = ActivityDate)

Sleeps2 <- sleep_Day %>% 
  mutate(SleepDay = mdy_hms(SleepDay)) %>% 
  rename(Date = SleepDay)

Intensities2 <- daily_Intensities %>%
  mutate(ActivityDay = mdy(ActivityDay)) %>%
  rename(Date = ActivityDay)

Steps2 <- daily_Steps %>%
  mutate(ActivityDay = mdy(ActivityDay)) %>%
  rename(Date = ActivityDay)


# Adding Activeness column
Activity_levels <- Activity2 %>%
  mutate(Day = weekdays(as.Date(Date)),
         Activity_levels = case_when(.$TotalSteps <= 5000 ~ "Sedentary",
                                     .$TotalSteps <= 7500 ~ "Low_Activities",
                                     .$TotalSteps <= 10000 ~ "Medium_Activities",
                                     .$TotalSteps <= 12500 ~ "Activities",
                                     .$TotalSteps > 12500 ~ "High_Activities"))

# Adding Sleep column
Sleeps_levels <- Sleeps2 %>%
  mutate(Sleeps_levels = case_when(.$TotalMinutesAsleep <= 360 ~ "Low_Sleep",
                                   .$TotalMinutesAsleep > 360 & TotalMinutesAsleep <= 510 ~ "Reasonalble_Sleep",
                                   .$TotalMinutesAsleep > 510 ~ "More_Sleep"))


#Sort Day levels
Activity_levels$Day <- factor(Activity_levels$Day, levels = c("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday")) 



# Merging the Activity and sleeps dataset
Activity_Sleep <- merge(Activity_levels, Sleeps_levels, by=c("Id", "Date"))

head(Activity_Sleep, 3)

# %% [markdown]
# ### **A.6 Plot for TotalMinutesAsleep vs Activity_levels 1**
#
# The density map shows the density of all sleep time occupied by different Activity_levels. It can be seen that Sedentary has the largest area, that is to say, the sleep time is the longest, on the contrary, the sleep time of Activities is the shortest.

# %%
# TotalMinutesAsleep vs Activity_levels 1
ggplot(Activity_Sleep, aes(x= TotalMinutesAsleep, fill = Activity_levels)) +
  geom_density(position = "fill") +
  labs(
    title = "TotalMinutesAsleep vs Activity_levels 1",
    subtitle = "Max_MinutesAsleep is 796",
    caption = "Source: FitBit Fitness Tracker Data",
    x = "TotalMinutesAsleep"
  )

# %% [markdown]
# ### **A.7 Plot of TotalMinutesAsleep vs Activity_levels 2**
#
# The ridge line graph is a variation of the density graph that prevents the density curves from overlapping, and I did it to show the peaks in sleep time for different Activity_levels and the general trend of sleep long distances. It can see that Activities are the steepest, because the sleep time span is narrow. On the contrary, Sedentary has the longest sleep time span and presents multiple fluctuation trends.

# %%
# TotalMinutesAsleep vs Activity_levels 2
ggplot(Activity_Sleep) +
  ggridges:: geom_density_ridges(aes(x = TotalMinutesAsleep, y = Activity_levels, fill = Activity_levels)) +
  labs(
    title = "TotalMinutesAsleep vs Activity_levels 2",
    subtitle = "Max_MinutesAsleep is 796",
    caption = "Source: FitBit Fitness Tracker Data",
    x = "TotalMinutesAsleep"
  )

# %% [markdown]
# ### **A.8 BoxPlot of ActivityLevels_vs_TotalMinutesAsleep**
#
# Box plots could be used when there are relatively few data points in each group and you need to show the distribution of the data in each group. Here, the box plot can show the distribution of different Activity_levels. It could observe that Sedentary has the widest distribution of scatter points, with Activities and Medium_Activities being the most concentrated, which proves that the sleep time of such users is relatively fixed, which is shorter than Sedentary users.

# %%
# BoxPlot_ActivityLevels_vs_TotalMinutesAsleep 
ggplot(Activity_Sleep, aes(x = Activity_levels, y = TotalMinutesAsleep, color = Activity_levels)) +
  geom_boxplot(width = 0.65) +
  geom_point(position = position_jitter(seed = 200, width = 0.25))+
  labs(
    title = "BoxPlot_ActivityLevels_vs_TotalMinutesAsleep",
    subtitle = "Total_Users = 413",
    caption = "Source: FitBit Fitness Tracker Data",
    x = "Activity_levels"
  )

# %% [markdown]
# ### **A.9 Plot of Activity_Sleep vs Calories vs Day**
#
# The figure displayed that the consumption of Calories on Thursday is the largest and has the largest span, and the consumption of Calories on Monday and Tuesday is the least. Sunday's sleeping area is the largest.

# %%
# Plot of TotalMinutesAsleep vs Calories vs Day
p <- ggplot(data=Activity_Sleep,
  mapping = aes(
    x = Calories,
    y = TotalMinutesAsleep,
    color = Day,
    fill = Day))
p + geom_point() +
  geom_smooth(method="loess") +
    labs(
    title = "TotalMinutesAsleep vs Calories vs Day",
    subtitle = "Total_Users = 413",
    caption = "Source: FitBit Fitness Tracker Data",
    x = "Calories"
  )

# %% [markdown]
# ### **A.10 Plot of TotalSteps_vs_WeekDay**
#
# The curve of the total number of steps in the first three days of the week fluctuates the same, and the peak value is almost the same, and the fluctuations have become larger and larger since Thursday. The peak on Sunday was the lowest. Also, Saturday is the highest in the week, the peak is also the highest.

# %%
# TotalSteps_vs_WeekDay
ggplot(Activity_Sleep, aes(x = TotalSteps, y = Day, col= factor(Day)), alpha= 0.4) +
 geom_density_ridges_gradient(scale = 3, rel_min_height = 0.01, gradient_lwd = 1.) +
  scale_x_continuous(expand = c(0, 0)) +
  scale_y_discrete(expand = expansion(mult = c(0.01, 0.25))) +
  scale_fill_viridis_c(name = "TotalSteps") +
  coord_cartesian(clip = "off") +
  labs(
    title = 'TotalSteps_vs_WeekDay',
    subtitle = "Total_Users = 413",
    caption = "Source: FitBit Fitness Tracker Data",
    x = "Total_Steps",
    fill = "# Cylinders"
  ) +
  theme_ridges(font_size = 13, grid = TRUE) + 
  theme(axis.title.y = element_blank())

# %% [markdown]
# ## **Daily Data Analysis**
#
# ### **B.1 Daily Activity Usage Data Analysis**
#
# According to the statistical correlation, the visual map was obtained, and the correlation between TotalSteps and Calories was obtained, which proved that the records of walking and Calories were consistent. But TotalSteps vs TotalMinutesAsleep and Calories vs TotalMinutesAsleep were both negatively correlated, proving that the two sets of data have opposite trends.

# %%
# Calculate the Daily Activity_levels prameters

# set min and max date value
max_date <- as.character(max(Activity_levels$Date))
min_date <- as.character(min(Activity_levels$Date))

# calculate different days between min and max date
different_days = length(unique(Activity_levels$Date))

# set max user value
max_users <- length(unique(Activity_levels$Id))

# set min and max TotalSteps value
max_TotalSteps <- max(Activity_levels$TotalSteps)
min_TotalSteps <- min(Activity_levels$TotalSteps)

# set avg user value, sum/(33*31)
Average_steps_Daily <- round(sum(Activity_levels$TotalSteps) / (max_users*different_days), digits = 0)

# %% [markdown]
# ### **B.2 Correlation for TotalSteps vs TotalMinutesAsleep vs Calories**

# %%
# SQL for Correlation of 3 parameters
Corr_SQL <- sqldf::sqldf('
   SELECT TotalSteps, Calories, TotalMinutesAsleep
   FROM Activity_Sleep')
head(Corr_SQL,3)

# %% [markdown]
# ### **B.3 Correlation for 3 parameters**

# %%
# Correlation for 3 parameters
corr_data <- as.data.frame(round(cor(Corr_SQL), 2))
corr_data$var1 <- rownames(corr_data)
data <- gather(corr_data, key = "var2", value = "corr", -var1)

head(data,3)

# %% [markdown]
# ### **B.4 Plot of Correlation for TotalSteps vs TotalMinutesAsleep vs Calories**

# %%
# Plot of Correlation

my_color <- brewer.pal(3, "Dark2")

ggplot(data, aes(var1, var2, fill = corr)) +
  geom_tile(colour = "black") +
  scale_fill_gradientn(colours = my_color)+
  geom_text(aes(label = corr), size = 5, colour = "black", alpha = 0.7) +
  theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1), 
        legend.title = element_blank()) +
  labs(title = "Correlation for TotalSteps vs TotalMinutesAsleep vs Calories", 
       subtitle = "Total_Users = 413",
       caption = "Source: FitBit Fitness Tracker Data")

# %% [markdown]
# ### **B.4 Overall of steps**

# %%
# Defination of Steps_level
Activity_levels2 <- Activity_levels %>%
  mutate(Steps_level = case_when(.$TotalSteps > Average_steps_Daily ~ 1, 
                                     .$TotalSteps <= Average_steps_Daily ~ 0), 
                                      Average_steps_Daily)

# Calculate the Total usage per day
Activity_levels3 <- Activity_levels2%>% 
  group_by(Date) %>% 
  summarise(total_users = length(unique(Activity_levels2$Id))) %>% 
  mutate(total_users)

# %%
Activity_levels_SQL <- sqldf::sqldf('
     SELECT Date, Steps_level, (SELECT count(Id) from Activity_levels2 GROUP BY Date) as TotalId_daily
        , count(Id) as Diff_level_steps
     FROM Activity_levels2
     GROUP BY Date, Steps_level
     ')

# %% [markdown]
# ### **B.5 TotalMinutesAsleep vs TotalSteps**
#
# "Step_level = 0" means TotalSteps less than Average_steps_Daily, "Step_level = 1" means TotalSteps more than Average_steps_Daily.

# %%
# Use SQL syntax to conduct the Activity_levels
Activity_levels_SQL <- sqldf::sqldf('
     SELECT Date, Steps_level, (SELECT count(Id) from Activity_levels2 GROUP BY Date) as TotalId_daily
        , count(Id) as Diff_level_steps
     FROM Activity_levels2
     GROUP BY Date, Steps_level
     ')
head(Activity_levels_SQL,3)

# %% [markdown]
# ### **B.6 Plot for Steps_level Daily Through one Month**
#
# "Step_level is Dark Blue" means TotalSteps less than Average_steps_Daily, "Step_level is Light Blue" means TotalSteps more than Average_steps_Daily.
# This plot displayed that there was 9 days' users whose value is lower than the average number of steps, and more users with more than the average number of steps on other days.

# %%
# Plot for Steps_level Daily

plot2 <- ggplot(data = Activity_levels_SQL, aes(x = Date, y = Diff_level_steps, fill = Steps_level)) + 
  geom_col(position = "dodge") +
  scale_y_continuous(expand = c(0, 0), limits = c(0, 36), breaks = seq(0,33, by = 2)) +
  scale_x_date(date_labels="%d %b '%y", breaks = "1 day", expand = c(.01, .01)) +
  theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1), 
        legend.title = element_blank()) +
  labs(title = "Steps_level Daily Through one Month", 
       subtitle = paste0(" Steps < Ave_steps is Dark Blue,   Steps >= Ave_steps is Light Blue "),
       caption = "Source: FitBit Fitness Tracker Data, Mobius") +
  xlab("Date") +
  ylab("Number of Users") +
  geom_hline(yintercept = max_users, linetype = "dashed")

plot2

# %% [markdown]
# ### **B.7 WeekDays vs TotalMinutesAsleep vs TotalSteps**

# %%
# WeekDays vs TotalMinutesAsleep vs TotalSteps

ggplot(Activity_Sleep, mapping = aes(x = TotalMinutesAsleep, y = TotalSteps, color = TotalMinutesAsleep)) +
  geom_point() +
  geom_smooth(method = "lm") +
  facet_wrap(~Day) +
  labs(title = "Total Steps vs Sleep_Minutes", x = "TotalMinutesAsleep") +
  scale_color_gradient(low = "#0000FF", high = "#FF1493") +
  
  theme(axis.text.x = element_text(angle = 90, vjust = 0.5, hjust=1), 
        legend.title = element_blank()) +
  labs(title = "Week days for TotalMinutesAsleep vs TotalSteps", 
       subtitle = paste0("Data for ", min_date, " to ", max_date, "\nAverage_steps_Daily: ", Average_steps_Daily, "\nmax_TotalSteps:", max_TotalSteps),
       caption = "Source: FitBit Fitness Tracker Data") +
  geom_hline(yintercept = Average_steps_Daily, linetype = "dashed", col = "red")+
  xlab("Total Minutes Asleep") + ylab("Total Steps Daily")

# %% [markdown]
# ##  **Hours Part**
#
# ### **C.1 Hours Part reorganization**
# Used Google Sheet to format the time columns, then extract the Date and 24 Hour numbers, also used IF function to switch 12-hour format to 24-hour format. Finally, merged the relative data set base on the same columns, in order to analyze the next step.

# %%
hourlySteps_merged <- read_csv("../input/fitbit-fitness-tracker-data/hourlySteps_merged.csv")
hourlyIntensities_merged <- read_csv("../input/fitbit-fitness-tracker-data/hourlyIntensities_merged.csv")
hourlyCalories_merged <- read_csv("../input/fitbit-fitness-tracker-data/hourlyCalories_merged.csv")

# %%
# Hours Part -Google Sheet format for the time columns

merge_1 <-merge(hourlyCalories_merged, hourlyIntensities_merged, by = c("Id","Date","Hours-24"))
Hours_merge_all <-merge(merge_1, hourlySteps_merged, by = c("Id","Date","Hours-24")) %>%
  select(Id, Date, 'Hours-24', Calories, TotalIntensity, StepTotal)

# %%
head(Hours_merge_all,3)

# %%
# Different Hours Parts

# set min and max date value
max_Calories_hourly <- as.character(max(Hours_merge_all$Calories))
min_Calories_hourly <- as.character(min(Hours_merge_all$Calories))


# set min and max TotalIntensity value
max_TotalIntensity_hourly <- max(Hours_merge_all$TotalIntensity)
min_TotalIntensity_hourly <- min(Hours_merge_all$TotalIntensity)


# set min and max TotalSteps value
max_TotalSteps_hourly <- max(Hours_merge_all$StepTotal)
min_TotalSteps_hourly <- min(Hours_merge_all$StepTotal)

# Visualization
Hours_merge_all$`Hours-24` <-as.numeric(Hours_merge_all$`Hours-24`)

# %% [markdown]
# ### **C.2 Plot of Hours_of_Calories**
# Calories is the highest during 14:00-18:00, and it is also the most concentrated during this period, The lowest Calories values exist daily between 02:00 am - 4:00 am, and 12:00 pm.

# %%
# Plot of Hours_of_Calories

p1_Calories <- ggplot(data = Hours_merge_all, aes(x=`Hours-24`, y=Calories, color= Calories)) +
  geom_point() +
  scale_x_continuous(limits = c(0, 24)) +
  scale_color_gradient(low = "#9AFF9A" , high = "#FF0000", na.value = "white") +
  geom_smooth(method = "gam", color = "blue") +
  labs(titles = "Hours_of_Calories", x= "24_Hours", y= "Calories(k)")+
  
  theme(axis.text.x = element_text(angle = 0, vjust = 0.5, hjust=1), 
        legend.title = element_blank()) +
  labs(title = "Calories for Each Hour", 
       subtitle = ("Data Points = 22099"),
       caption = "Source: FitBit Fitness Tracker Data") 

p1_Calories

# %% [markdown]
# ### **C.3 Plot of Hours_of_TotalIntensity**
#
# The value of Intensity is very high from 8:00-19:00 every day.

# %%
# Plot of Hours_of_TotalIntensity
p2_TotalIntensity <- ggplot(data = Hours_merge_all, aes(x=`Hours-24`, y=TotalIntensity, color= TotalIntensity)) +
  geom_point() +
  scale_x_continuous(limits = c(0, 24)) +
  scale_color_gradient(low = "#87CEEB" , high = "#FF0000", na.value = "white") +
  geom_smooth(method = "gam", color = "blue") +
  labs(titles = "Hours_of_TotalIntensity", x= "24_Hours", y= "TotalIntensity") +
  
  theme(axis.text.x = element_text(angle = 0, vjust = 0.5, hjust=1), 
        legend.title = element_blank()) +
  labs(title = "TotalIntensity for Each Hour", 
       subtitle = ("Data Points = 22099"),
       caption = "Source: FitBit Fitness Tracker Data") 

p2_TotalIntensity

# %% [markdown]
# ### **C.4 Plot of Hours_of_StepTotal**
#
# Steps has an upward trend from 6:00-9:00, 11:00:19:00.

# %%
# C.5 Plot of Hours_of_StepTotal
p3_TotalSteps <- ggplot(data = Hours_merge_all, aes(x=`Hours-24`, y=StepTotal, color= StepTotal)) +
  geom_point() +
  scale_x_continuous(limits = c(0, 24)) +
  scale_color_gradient(low = "#CAFF70" , high = "#0000FF", na.value = "white") +
  geom_smooth(method = "gam", color = "blue") +
  labs(titles = "Hours_of_TotalSteps", x= "24_Hours", y= "TotalSteps") +
  
  theme(axis.text.x = element_text(angle = 0, vjust = 0.5, hjust=1), 
        legend.title = element_blank()) +
  labs(title = "TotalSteps for Each Hour", 
       subtitle = ("Data Points = 22099"),
       caption = "Source: FitBit Fitness Tracker Data") 

p3_TotalSteps

# %% [markdown]
# ### ** Step6: Act- Recommendations **
#
# * 1) Since the stakeholders only provided data from a long time ago, the specific data is one month from April 12, 2016 to May 12, 2016, and the data users are only 33. So the sample size is small, so there is sample bias. Therefore, the validity of this data may no longer be informative. So I recommend Bellabeat could provid an up-to-date set of data to ensure data reliablity. If more realistic analysis results are required, we need more sample data. In conclusion, this analysis report only represents the analysis results of 33 small samples.
#
#
# * 2) Through comprehensive data analysis, the functions of Activity, Intensities, and Sleeps users cover more comprehensively 100%. Followed by the Steps function, accounting for 72.73%. The leaset used function is Weight users, which only accounts for 24.24%.
#
#   The data suggest that Bellabeat could focus more on the promotion and function development of Activity, Intensities, and Sleeps because these three functions are customers' favourite.
#
#    The Weight function is the least popular, which is the low usage maybe due to the protection of personal privacy by customers, or because Weight is an item that cannot be encouraged in a short time for women, so I suggest that Bellabeat could change its thinking and display the results of Weight switch to a form of encouragement or motivation, such as getting a cut emoji or background image on Bellabeat's customer App, due to the customer losing weight from the previous day.
#
#    The usage of the Sleep function is in the middle. This may be because not all users are willing to carry accessories such as watches and bracelets when sleeping. After all, they will affect the quality of sleep. Therefore, I recommend that Bellabeat company use more comfortable product materials, which could allow more users to use it while sleeping.
#
#
# * 3) Through the analysis of ActivityLevels, TotalMinutesAsleep, Calories, and WeekDay, people who exercise a little bit sleep longer and sleep the longest on Saturday. Sleep time during the workday is relatively short. Calories are consumed the most on Thursday and the least on Monday and Tuesday.
#
#     According to the data, I suggest that Bellabeat could add sleep reminder functions, such as recommending users not to stay up late, reminding the sleep time of the day in advance, etc., so that customers could maintain regular work and rest habits. Also, customers could remind to increase exercise appropriately on Monday and Tuesday to increase the consumption of Calories. Therefore, the addition reminder function could keep customers healthy.
